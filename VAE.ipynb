# %% [markdown]
# ## VAE

# %% [markdown]
# Import required packages

# %%
import torch
from torch import optim
from models.ResVAE import (
    ResVariationalAutoEncoder,
)  # Assuming you have a VAE model defined in 'model.py'
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
from train import load_cw
from utils.geodesicwelding import geodesicwelding


DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
MAT_PATH = "data/preprocessed.mat"

cw = load_cw(MAT_PATH)
cw_tensor = torch.tensor(cw)
train_data = TensorDataset(cw_tensor)

# %% [markdown]
# Training

# %%
# Configuration

INPUT_DIM = 100  # Adjusted input dimension to match your complex data
H_DIM = 2000
Z_DIM = 4
H_LAYERS = [2]
LR_RATE = 1e-4
BATCH_SIZE = 1024


train_loader = DataLoader(
    dataset=train_data, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True
)

## Init model
model = ResVariationalAutoEncoder(
    input_dim=INPUT_DIM, h_dim=H_DIM, h_layers=H_LAYERS, z_dim=Z_DIM
).to(DEVICE)
model.initial()

## Load model
# model = torch.load('VAE_theta+bias1.pth')

optimizer = optim.Adam(
    model.parameters(), lr=LR_RATE, weight_decay=1e-5, betas=(0.5, 0.999)
)
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[8000], gamma=0.5)

model.to(DEVICE)

loader_size = len(train_loader)
loss_list_dict = {}
# loss_list = np.zeros(loader_size)  # To store reconstruction diff losses
# recon_loss_list = np.zeros(loader_size)  # To store reconstruction losses
# kl_loss_list = np.zeros(loader_size)         # To store KL divergence losses

# %%
NUM_EPOCHS = 20000


def get_kl_rate(epoch, n=500, m=1000):
    if epoch < m:
        return 0
    else:
        return (epoch % n) / n


kl_rate = 0.1
model.train()
for epoch in range(NUM_EPOCHS):
    for i, [data] in enumerate(train_loader):
        data = data.to(DEVICE, dtype=torch.float32).view(data.shape[0], INPUT_DIM)
        x_reconstructed, mu, sigma = model(data)

        # Compute loss
        # kl_rate = get_kl_rate(epoch)
        loss_dict = model.loss(x_reconstructed, data, mu, sigma, kl_rate)

        # Backprop
        optimizer.zero_grad()
        loss_dict["loss"].backward()
        optimizer.step()
        scheduler.step()

        # Append losses to the lists
        for k, v in loss_dict.items():
            if k not in loss_list_dict:
                loss_list_dict[k] = np.zeros(loader_size)

            loss_list_dict[k][i] = v.item()

    # Calculate and print average losses for this epoch
    # avg_loss = loss_list.sum() / data_size
    # avg_recon_loss = recon_loss_list.sum() / data_size
    # avg_kl_loss = kl_loss_list.sum() / data_size
    # avg_loss = loss_list.mean()
    # avg_recon_loss = recon_loss_list.mean()
    # avg_kl_loss = kl_loss_list.mean()
    # avg_true_loss = true_loss_list.mean()

    if epoch % 100 == 0:
        print(
            f"Epoch {epoch}/{NUM_EPOCHS} | {', '.join([f'{k}: {v.mean():.4f}' for k, v in loss_list_dict.items()])}"
        )

    if epoch % 1000 == 0:
        torch.save(model, "checkpoints/ResVAE.pth")
# Out:
# Epoch 0/20000 | loss: 1299.3394, recon_loss: 1298.6039, kl_loss: 7.3547, true_loss: 1.6033
# Epoch 100/20000 | loss: 44.3271, recon_loss: 41.1596, kl_loss: 31.6742, true_loss: 0.2080
# Epoch 200/20000 | loss: 32.3323, recon_loss: 30.0177, kl_loss: 23.1462, true_loss: 0.1633
# Epoch 300/20000 | loss: 26.4127, recon_loss: 24.3863, kl_loss: 20.2636, true_loss: 0.1384
# Epoch 400/20000 | loss: 26.2590, recon_loss: 24.1038, kl_loss: 21.5523, true_loss: 0.1361
# Epoch 500/20000 | loss: 23.4916, recon_loss: 21.4187, kl_loss: 20.7290, true_loss: 0.1229
# Epoch 600/20000 | loss: 22.9966, recon_loss: 20.9039, kl_loss: 20.9272, true_loss: 0.1223
# Epoch 700/20000 | loss: 20.4139, recon_loss: 18.3950, kl_loss: 20.1893, true_loss: 0.1051
# Epoch 800/20000 | loss: 17.8128, recon_loss: 15.7789, kl_loss: 20.3382, true_loss: 0.0905
# Epoch 900/20000 | loss: 16.1557, recon_loss: 14.0746, kl_loss: 20.8118, true_loss: 0.0790
# Epoch 1000/20000 | loss: 16.6831, recon_loss: 14.7125, kl_loss: 19.7059, true_loss: 0.0821
# Epoch 1100/20000 | loss: 17.3148, recon_loss: 15.1949, kl_loss: 21.1986, true_loss: 0.0864
# Epoch 1200/20000 | loss: 17.1705, recon_loss: 15.2622, kl_loss: 19.0830, true_loss: 0.0892
# Epoch 1300/20000 | loss: 17.3434, recon_loss: 15.2214, kl_loss: 21.2203, true_loss: 0.0858
# Epoch 1400/20000 | loss: 15.6384, recon_loss: 13.6204, kl_loss: 20.1803, true_loss: 0.0770
# Epoch 1500/20000 | loss: 11.7306, recon_loss: 9.6571, kl_loss: 20.7344, true_loss: 0.0536
# Epoch 1600/20000 | loss: 21.4669, recon_loss: 19.0719, kl_loss: 23.9499, true_loss: 0.1087
# Epoch 1700/20000 | loss: 11.5272, recon_loss: 9.4272, kl_loss: 21.0004, true_loss: 0.0519
# Epoch 1800/20000 | loss: 10.4629, recon_loss: 8.4940, kl_loss: 19.6898, true_loss: 0.0492
# Epoch 1900/20000 | loss: 11.7490, recon_loss: 9.7075, kl_loss: 20.4149, true_loss: 0.0549
# Epoch 2000/20000 | loss: 9.4835, recon_loss: 7.5091, kl_loss: 19.7436, true_loss: 0.0426
# Epoch 2100/20000 | loss: 8.6389, recon_loss: 6.6064, kl_loss: 20.3253, true_loss: 0.0391
# Epoch 2200/20000 | loss: 11.0207, recon_loss: 9.1162, kl_loss: 19.0456, true_loss: 0.0505
# Epoch 2300/20000 | loss: 14.1833, recon_loss: 12.0499, kl_loss: 21.3343, true_loss: 0.0683
# Epoch 2400/20000 | loss: 8.0475, recon_loss: 6.1780, kl_loss: 18.6948, true_loss: 0.0351
# Epoch 2500/20000 | loss: 9.1544, recon_loss: 7.2337, kl_loss: 19.2070, true_loss: 0.0395
# Epoch 2600/20000 | loss: 16.4030, recon_loss: 14.2986, kl_loss: 21.0439, true_loss: 0.0776
# Epoch 2700/20000 | loss: 6.4191, recon_loss: 4.4647, kl_loss: 19.5436, true_loss: 0.0262
# Epoch 2800/20000 | loss: 6.2202, recon_loss: 4.2894, kl_loss: 19.3079, true_loss: 0.0232
# Epoch 2900/20000 | loss: 6.2028, recon_loss: 4.3253, kl_loss: 18.7756, true_loss: 0.0252
# Epoch 3000/20000 | loss: 5.8440, recon_loss: 3.7876, kl_loss: 20.5635, true_loss: 0.0225
# Epoch 3100/20000 | loss: 6.1638, recon_loss: 4.0948, kl_loss: 20.6897, true_loss: 0.0252
# Epoch 3200/20000 | loss: 12.5285, recon_loss: 10.5322, kl_loss: 19.9627, true_loss: 0.0579
# Epoch 3300/20000 | loss: 6.8895, recon_loss: 4.9481, kl_loss: 19.4144, true_loss: 0.0276
# Epoch 3400/20000 | loss: 5.7713, recon_loss: 3.9605, kl_loss: 18.1077, true_loss: 0.0233
# Epoch 3500/20000 | loss: 4.3512, recon_loss: 2.5030, kl_loss: 18.4818, true_loss: 0.0157
# Epoch 3600/20000 | loss: 10.1560, recon_loss: 7.7598, kl_loss: 23.9619, true_loss: 0.0428
# Epoch 3700/20000 | loss: 4.2324, recon_loss: 2.4228, kl_loss: 18.0965, true_loss: 0.0157
# Epoch 3800/20000 | loss: 3.5194, recon_loss: 1.4737, kl_loss: 20.4568, true_loss: 0.0091
# Epoch 3900/20000 | loss: 3.6424, recon_loss: 1.8179, kl_loss: 18.2454, true_loss: 0.0118
# Epoch 4000/20000 | loss: 3.4842, recon_loss: 1.6724, kl_loss: 18.1183, true_loss: 0.0109
# Epoch 4100/20000 | loss: 2.7792, recon_loss: 0.9713, kl_loss: 18.0790, true_loss: 0.0065
# Epoch 4200/20000 | loss: 4.7868, recon_loss: 2.5037, kl_loss: 22.8303, true_loss: 0.0168
# Epoch 4300/20000 | loss: 2.7387, recon_loss: 0.9697, kl_loss: 17.6897, true_loss: 0.0058
# Epoch 4400/20000 | loss: 2.8555, recon_loss: 0.8592, kl_loss: 19.9623, true_loss: 0.0057
# Epoch 4500/20000 | loss: 23.6244, recon_loss: 21.6108, kl_loss: 20.1358, true_loss: 0.1195
# Epoch 4600/20000 | loss: 2.5011, recon_loss: 0.7492, kl_loss: 17.5185, true_loss: 0.0048
# Epoch 4700/20000 | loss: 2.4314, recon_loss: 0.5990, kl_loss: 18.3244, true_loss: 0.0041
# Epoch 4800/20000 | loss: 2.3687, recon_loss: 0.6384, kl_loss: 17.3021, true_loss: 0.0040
# Epoch 4900/20000 | loss: 2.5823, recon_loss: 0.9802, kl_loss: 16.0207, true_loss: 0.0064
# Epoch 5000/20000 | loss: 9.4337, recon_loss: 7.2204, kl_loss: 22.1333, true_loss: 0.0440
# Epoch 5100/20000 | loss: 2.5939, recon_loss: 0.6243, kl_loss: 19.6963, true_loss: 0.0043
# Epoch 5200/20000 | loss: 2.2531, recon_loss: 0.4169, kl_loss: 18.3619, true_loss: 0.0028
# Epoch 5300/20000 | loss: 2.1034, recon_loss: 0.3521, kl_loss: 17.5123, true_loss: 0.0024
# Epoch 5400/20000 | loss: 3.0028, recon_loss: 0.9994, kl_loss: 20.0339, true_loss: 0.0068
# Epoch 5500/20000 | loss: 2.0564, recon_loss: 0.3711, kl_loss: 16.8536, true_loss: 0.0024
# Epoch 5600/20000 | loss: 1.8889, recon_loss: 0.3563, kl_loss: 15.3266, true_loss: 0.0022
# Epoch 5700/20000 | loss: 2.0770, recon_loss: 0.5144, kl_loss: 15.6254, true_loss: 0.0031
# Epoch 5800/20000 | loss: 1.9346, recon_loss: 0.4577, kl_loss: 14.7691, true_loss: 0.0031
# Epoch 5900/20000 | loss: 1.9707, recon_loss: 0.4126, kl_loss: 15.5809, true_loss: 0.0027
# Epoch 6000/20000 | loss: 2.0098, recon_loss: 0.5717, kl_loss: 14.3811, true_loss: 0.0050
# Epoch 6100/20000 | loss: 1.8555, recon_loss: 0.2621, kl_loss: 15.9341, true_loss: 0.0017
# Epoch 6200/20000 | loss: 1.9182, recon_loss: 0.4264, kl_loss: 14.9173, true_loss: 0.0023
# Epoch 6300/20000 | loss: 17.5893, recon_loss: 16.0897, kl_loss: 14.9962, true_loss: 0.0830
# Epoch 6400/20000 | loss: 2.2293, recon_loss: 0.7576, kl_loss: 14.7174, true_loss: 0.0042
# Epoch 6500/20000 | loss: 5.9311, recon_loss: 3.7302, kl_loss: 22.0090, true_loss: 0.0215
# Epoch 6600/20000 | loss: 2.2777, recon_loss: 0.4564, kl_loss: 18.2123, true_loss: 0.0032
# Epoch 6700/20000 | loss: 1.7382, recon_loss: 0.2366, kl_loss: 15.0168, true_loss: 0.0015
# Epoch 6800/20000 | loss: 1.7106, recon_loss: 0.2937, kl_loss: 14.1693, true_loss: 0.0020
# Epoch 6900/20000 | loss: 1.9189, recon_loss: 0.4756, kl_loss: 14.4327, true_loss: 0.0031
# Epoch 7000/20000 | loss: 1.7796, recon_loss: 0.3764, kl_loss: 14.0320, true_loss: 0.0029
# Epoch 7100/20000 | loss: 2.1730, recon_loss: 0.3402, kl_loss: 18.3274, true_loss: 0.0023
# Epoch 7200/20000 | loss: 5.3257, recon_loss: 3.2788, kl_loss: 20.4692, true_loss: 0.0203
# Epoch 7300/20000 | loss: 1.8069, recon_loss: 0.4401, kl_loss: 13.6680, true_loss: 0.0033
# Epoch 7400/20000 | loss: 24.9228, recon_loss: 22.7246, kl_loss: 21.9815, true_loss: 0.1236
# Epoch 7500/20000 | loss: 1.6885, recon_loss: 0.2262, kl_loss: 14.6229, true_loss: 0.0015
# Epoch 7600/20000 | loss: 1.6731, recon_loss: 0.3457, kl_loss: 13.2742, true_loss: 0.0022
# Epoch 7700/20000 | loss: 1.6767, recon_loss: 0.2950, kl_loss: 13.8171, true_loss: 0.0017
# Epoch 7800/20000 | loss: 1.8241, recon_loss: 0.3021, kl_loss: 15.2200, true_loss: 0.0019
# Epoch 7900/20000 | loss: 1.7573, recon_loss: 0.4048, kl_loss: 13.5253, true_loss: 0.0025
# Epoch 8000/20000 | loss: 1.6164, recon_loss: 0.2533, kl_loss: 13.6308, true_loss: 0.0015
# Epoch 8100/20000 | loss: 1.4934, recon_loss: 0.1739, kl_loss: 13.1947, true_loss: 0.0011
# Epoch 8200/20000 | loss: 1.4711, recon_loss: 0.1743, kl_loss: 12.9677, true_loss: 0.0011
# Epoch 8300/20000 | loss: 1.4524, recon_loss: 0.1724, kl_loss: 12.8007, true_loss: 0.0011
# Epoch 8400/20000 | loss: 1.4324, recon_loss: 0.1687, kl_loss: 12.6368, true_loss: 0.0010
# Epoch 8500/20000 | loss: 1.4280, recon_loss: 0.1695, kl_loss: 12.5850, true_loss: 0.0011
# Epoch 8600/20000 | loss: 1.4270, recon_loss: 0.1725, kl_loss: 12.5454, true_loss: 0.0011
# Epoch 8700/20000 | loss: 1.4152, recon_loss: 0.1684, kl_loss: 12.4676, true_loss: 0.0011
# Epoch 8800/20000 | loss: 1.4087, recon_loss: 0.1655, kl_loss: 12.4323, true_loss: 0.0011
# Epoch 8900/20000 | loss: 1.4040, recon_loss: 0.1717, kl_loss: 12.3231, true_loss: 0.0011
# Epoch 9000/20000 | loss: 1.3985, recon_loss: 0.1685, kl_loss: 12.3000, true_loss: 0.0011
# Epoch 9100/20000 | loss: 1.3966, recon_loss: 0.1663, kl_loss: 12.3029, true_loss: 0.0012
# Epoch 9200/20000 | loss: 1.3974, recon_loss: 0.1710, kl_loss: 12.2639, true_loss: 0.0011
# Epoch 9300/20000 | loss: 1.4083, recon_loss: 0.1865, kl_loss: 12.2176, true_loss: 0.0012
# Epoch 9400/20000 | loss: 4.2816, recon_loss: 2.5452, kl_loss: 17.3646, true_loss: 0.0180
# Epoch 9500/20000 | loss: 1.4438, recon_loss: 0.1673, kl_loss: 12.7644, true_loss: 0.0011
# Epoch 9600/20000 | loss: 1.4236, recon_loss: 0.1814, kl_loss: 12.4220, true_loss: 0.0011
# Epoch 9700/20000 | loss: 1.4526, recon_loss: 0.2204, kl_loss: 12.3221, true_loss: 0.0015
# Epoch 9800/20000 | loss: 1.4658, recon_loss: 0.2365, kl_loss: 12.2925, true_loss: 0.0015
# Epoch 9900/20000 | loss: 1.4269, recon_loss: 0.2127, kl_loss: 12.1420, true_loss: 0.0013
# Epoch 10000/20000 | loss: 1.5390, recon_loss: 0.2270, kl_loss: 13.1203, true_loss: 0.0015
# Epoch 10100/20000 | loss: 1.4428, recon_loss: 0.1808, kl_loss: 12.6194, true_loss: 0.0011
# Epoch 10200/20000 | loss: 1.4270, recon_loss: 0.1940, kl_loss: 12.3293, true_loss: 0.0012
# Epoch 10300/20000 | loss: 1.4691, recon_loss: 0.1804, kl_loss: 12.8870, true_loss: 0.0011
# Epoch 10400/20000 | loss: 1.4118, recon_loss: 0.1666, kl_loss: 12.4520, true_loss: 0.0011
# Epoch 10500/20000 | loss: 1.4022, recon_loss: 0.1773, kl_loss: 12.2494, true_loss: 0.0012
# Epoch 10600/20000 | loss: 2.1816, recon_loss: 0.6713, kl_loss: 15.1025, true_loss: 0.0036
# Epoch 10700/20000 | loss: 1.5024, recon_loss: 0.2089, kl_loss: 12.9354, true_loss: 0.0013
# Epoch 10800/20000 | loss: 1.4423, recon_loss: 0.1913, kl_loss: 12.5103, true_loss: 0.0012
# Epoch 10900/20000 | loss: 1.4525, recon_loss: 0.2095, kl_loss: 12.4303, true_loss: 0.0013
# Epoch 11000/20000 | loss: 1.4160, recon_loss: 0.1924, kl_loss: 12.2355, true_loss: 0.0011
# Epoch 11100/20000 | loss: 1.4198, recon_loss: 0.2076, kl_loss: 12.1221, true_loss: 0.0014
# Epoch 11200/20000 | loss: 1.4568, recon_loss: 0.2417, kl_loss: 12.1510, true_loss: 0.0014
# Epoch 11300/20000 | loss: 2.0885, recon_loss: 0.5481, kl_loss: 15.4036, true_loss: 0.0052
# Epoch 11400/20000 | loss: 1.5022, recon_loss: 0.1989, kl_loss: 13.0337, true_loss: 0.0013
# Epoch 11500/20000 | loss: 1.4575, recon_loss: 0.1908, kl_loss: 12.6669, true_loss: 0.0014
# Epoch 11600/20000 | loss: 1.4403, recon_loss: 0.1936, kl_loss: 12.4674, true_loss: 0.0013
# Epoch 11700/20000 | loss: 1.4637, recon_loss: 0.2312, kl_loss: 12.3260, true_loss: 0.0014
# Epoch 11800/20000 | loss: 1.5369, recon_loss: 0.3097, kl_loss: 12.2718, true_loss: 0.0022
# Epoch 11900/20000 | loss: 1.4258, recon_loss: 0.2071, kl_loss: 12.1876, true_loss: 0.0014
# Epoch 12000/20000 | loss: 1.9518, recon_loss: 0.5615, kl_loss: 13.9030, true_loss: 0.0035
# Epoch 12100/20000 | loss: 1.5153, recon_loss: 0.2309, kl_loss: 12.8440, true_loss: 0.0015
# Epoch 12200/20000 | loss: 1.5948, recon_loss: 0.2225, kl_loss: 13.7234, true_loss: 0.0015
# Epoch 12300/20000 | loss: 1.4671, recon_loss: 0.1946, kl_loss: 12.7258, true_loss: 0.0013
# Epoch 12400/20000 | loss: 1.4270, recon_loss: 0.1779, kl_loss: 12.4908, true_loss: 0.0012
# Epoch 12500/20000 | loss: 1.4133, recon_loss: 0.1869, kl_loss: 12.2645, true_loss: 0.0012
# Epoch 12600/20000 | loss: 1.4014, recon_loss: 0.1811, kl_loss: 12.2030, true_loss: 0.0011
# Epoch 12700/20000 | loss: 1.4318, recon_loss: 0.2190, kl_loss: 12.1276, true_loss: 0.0015
# Epoch 12800/20000 | loss: 1.4389, recon_loss: 0.1769, kl_loss: 12.6200, true_loss: 0.0012
# Epoch 12900/20000 | loss: 1.4097, recon_loss: 0.1861, kl_loss: 12.2369, true_loss: 0.0012
# Epoch 13000/20000 | loss: 1.3862, recon_loss: 0.1766, kl_loss: 12.0958, true_loss: 0.0012
# Epoch 13100/20000 | loss: 1.4054, recon_loss: 0.2052, kl_loss: 12.0016, true_loss: 0.0013
# Epoch 13200/20000 | loss: 1.3906, recon_loss: 0.1950, kl_loss: 11.9557, true_loss: 0.0014
# Epoch 13300/20000 | loss: 1.3478, recon_loss: 0.1679, kl_loss: 11.7991, true_loss: 0.0012
# Epoch 13400/20000 | loss: 1.3802, recon_loss: 0.1941, kl_loss: 11.8605, true_loss: 0.0012
# Epoch 13500/20000 | loss: 1.8374, recon_loss: 0.3723, kl_loss: 14.6507, true_loss: 0.0028
# Epoch 13600/20000 | loss: 1.4178, recon_loss: 0.1876, kl_loss: 12.3012, true_loss: 0.0013
# Epoch 13700/20000 | loss: 1.3536, recon_loss: 0.1450, kl_loss: 12.0859, true_loss: 0.0010
# Epoch 13800/20000 | loss: 1.3533, recon_loss: 0.1537, kl_loss: 11.9956, true_loss: 0.0010
# Epoch 13900/20000 | loss: 1.3562, recon_loss: 0.1732, kl_loss: 11.8304, true_loss: 0.0011
# Epoch 14000/20000 | loss: 1.3509, recon_loss: 0.1687, kl_loss: 11.8214, true_loss: 0.0011
# Epoch 14100/20000 | loss: 1.3774, recon_loss: 0.1961, kl_loss: 11.8125, true_loss: 0.0013
# Epoch 14200/20000 | loss: 1.3923, recon_loss: 0.2137, kl_loss: 11.7863, true_loss: 0.0014
# Epoch 14300/20000 | loss: 1.3692, recon_loss: 0.1975, kl_loss: 11.7167, true_loss: 0.0013
# Epoch 14400/20000 | loss: 1.3695, recon_loss: 0.2033, kl_loss: 11.6620, true_loss: 0.0013
# Epoch 14500/20000 | loss: 1.4364, recon_loss: 0.1894, kl_loss: 12.4704, true_loss: 0.0013
# Epoch 14600/20000 | loss: 1.3616, recon_loss: 0.1535, kl_loss: 12.0804, true_loss: 0.0010
# Epoch 14700/20000 | loss: 1.3362, recon_loss: 0.1593, kl_loss: 11.7696, true_loss: 0.0012
# Epoch 14800/20000 | loss: 1.3478, recon_loss: 0.1654, kl_loss: 11.8241, true_loss: 0.0012
# Epoch 14900/20000 | loss: 1.3559, recon_loss: 0.1906, kl_loss: 11.6526, true_loss: 0.0011
# Epoch 15000/20000 | loss: 1.3514, recon_loss: 0.1891, kl_loss: 11.6228, true_loss: 0.0012
# Epoch 15100/20000 | loss: 1.3351, recon_loss: 0.1756, kl_loss: 11.5955, true_loss: 0.0011
# Epoch 15200/20000 | loss: 21.6979, recon_loss: 20.0201, kl_loss: 16.7774, true_loss: 0.1025
# Epoch 15300/20000 | loss: 1.3886, recon_loss: 0.1695, kl_loss: 12.1913, true_loss: 0.0012
# Epoch 15400/20000 | loss: 1.3314, recon_loss: 0.1485, kl_loss: 11.8287, true_loss: 0.0010
# Epoch 15500/20000 | loss: 1.3231, recon_loss: 0.1520, kl_loss: 11.7118, true_loss: 0.0010
# Epoch 15600/20000 | loss: 1.3136, recon_loss: 0.1476, kl_loss: 11.6601, true_loss: 0.0009
# Epoch 15700/20000 | loss: 1.3177, recon_loss: 0.1665, kl_loss: 11.5119, true_loss: 0.0010
# Epoch 15800/20000 | loss: 1.3210, recon_loss: 0.1659, kl_loss: 11.5514, true_loss: 0.0013
# Epoch 15900/20000 | loss: 1.3299, recon_loss: 0.1747, kl_loss: 11.5520, true_loss: 0.0010
# Epoch 16000/20000 | loss: 1.3112, recon_loss: 0.1660, kl_loss: 11.4524, true_loss: 0.0010
# Epoch 16100/20000 | loss: 1.3137, recon_loss: 0.1725, kl_loss: 11.4120, true_loss: 0.0011
# Epoch 16200/20000 | loss: 1.3514, recon_loss: 0.2108, kl_loss: 11.4062, true_loss: 0.0013
# Epoch 16300/20000 | loss: 1.3181, recon_loss: 0.1870, kl_loss: 11.3103, true_loss: 0.0012
# Epoch 16400/20000 | loss: 1.3535, recon_loss: 0.2103, kl_loss: 11.4319, true_loss: 0.0013
# Epoch 16500/20000 | loss: 3.6861, recon_loss: 2.0816, kl_loss: 16.0443, true_loss: 0.0138
# Epoch 16600/20000 | loss: 1.3888, recon_loss: 0.1716, kl_loss: 12.1720, true_loss: 0.0011
# Epoch 16700/20000 | loss: 1.3312, recon_loss: 0.1521, kl_loss: 11.7910, true_loss: 0.0010
# Epoch 16800/20000 | loss: 1.3216, recon_loss: 0.1574, kl_loss: 11.6425, true_loss: 0.0010
# Epoch 16900/20000 | loss: 1.3162, recon_loss: 0.1618, kl_loss: 11.5443, true_loss: 0.0011
# Epoch 17000/20000 | loss: 1.3180, recon_loss: 0.1714, kl_loss: 11.4656, true_loss: 0.0011
# Epoch 17100/20000 | loss: 1.3724, recon_loss: 0.2255, kl_loss: 11.4686, true_loss: 0.0015
# Epoch 17200/20000 | loss: 1.3079, recon_loss: 0.1724, kl_loss: 11.3544, true_loss: 0.0011
# Epoch 17300/20000 | loss: 1.6787, recon_loss: 0.3351, kl_loss: 13.4359, true_loss: 0.0025
# Epoch 17400/20000 | loss: 1.4238, recon_loss: 0.1832, kl_loss: 12.4059, true_loss: 0.0012
# Epoch 17500/20000 | loss: 1.3994, recon_loss: 0.1920, kl_loss: 12.0746, true_loss: 0.0013
# Epoch 17600/20000 | loss: 1.3692, recon_loss: 0.1795, kl_loss: 11.8962, true_loss: 0.0012
# Epoch 17700/20000 | loss: 1.3476, recon_loss: 0.1657, kl_loss: 11.8191, true_loss: 0.0012
# Epoch 17800/20000 | loss: 1.3320, recon_loss: 0.1620, kl_loss: 11.7002, true_loss: 0.0011
# Epoch 17900/20000 | loss: 1.3578, recon_loss: 0.1887, kl_loss: 11.6910, true_loss: 0.0012
# Epoch 18000/20000 | loss: 1.3251, recon_loss: 0.1670, kl_loss: 11.5810, true_loss: 0.0011
# Epoch 18100/20000 | loss: 1.3349, recon_loss: 0.1855, kl_loss: 11.4934, true_loss: 0.0013
# Epoch 18200/20000 | loss: 1.3455, recon_loss: 0.1970, kl_loss: 11.4851, true_loss: 0.0013
# Epoch 18300/20000 | loss: 1.3290, recon_loss: 0.1783, kl_loss: 11.5070, true_loss: 0.0011
# Epoch 18400/20000 | loss: 1.4027, recon_loss: 0.1667, kl_loss: 12.3600, true_loss: 0.0011
# Epoch 18500/20000 | loss: 1.3182, recon_loss: 0.1399, kl_loss: 11.7829, true_loss: 0.0009
# Epoch 18600/20000 | loss: 1.3049, recon_loss: 0.1440, kl_loss: 11.6093, true_loss: 0.0010
# Epoch 18700/20000 | loss: 1.2935, recon_loss: 0.1515, kl_loss: 11.4201, true_loss: 0.0009
# Epoch 18800/20000 | loss: 1.3058, recon_loss: 0.1634, kl_loss: 11.4241, true_loss: 0.0011
# Epoch 18900/20000 | loss: 1.3114, recon_loss: 0.1677, kl_loss: 11.4367, true_loss: 0.0013
# Epoch 19000/20000 | loss: 1.3285, recon_loss: 0.1940, kl_loss: 11.3444, true_loss: 0.0013
# Epoch 19100/20000 | loss: 1.3014, recon_loss: 0.1715, kl_loss: 11.2994, true_loss: 0.0011
# Epoch 19200/20000 | loss: 1.2910, recon_loss: 0.1578, kl_loss: 11.3320, true_loss: 0.0010
# Epoch 19300/20000 | loss: 1.3107, recon_loss: 0.1841, kl_loss: 11.2657, true_loss: 0.0012
# Epoch 19400/20000 | loss: 1.3039, recon_loss: 0.1845, kl_loss: 11.1935, true_loss: 0.0012
# Epoch 19500/20000 | loss: 1.3050, recon_loss: 0.1787, kl_loss: 11.2629, true_loss: 0.0012
# Epoch 19600/20000 | loss: 1.2932, recon_loss: 0.1755, kl_loss: 11.1777, true_loss: 0.0011
# Epoch 19700/20000 | loss: 1.3229, recon_loss: 0.1965, kl_loss: 11.2636, true_loss: 0.0015
# Epoch 19800/20000 | loss: 31.3984, recon_loss: 29.7664, kl_loss: 16.3203, true_loss: 0.1601
# Epoch 19900/20000 | loss: 2.3823, recon_loss: 0.9387, kl_loss: 14.4359, true_loss: 0.0052

# %%
c = cw[np.random.choice(range(cw.shape[0]), 100)]
p = 1 / np.exp(c)
print(p.mean(), p.std())
plt.hist(p.reshape(-1), bins=100)
plt.title("Original Distribution of Ground Truth ")
# Out:
# 0.06283185 0.06270894
# Text(0.5, 1.0, 'Original Distribution of Ground Truth ')

# %%
c = cw[np.random.choice(range(cw.shape[0]), 100)]
print(c.mean(), c.std())
plt.hist(c.reshape(-1), bins=100)
plt.title("Distribution of Ground Truth Activated by 1/e^x")
# Out:
# 3.182104 1.0573868
# Text(0.5, 1.0, 'Distribution of Ground Truth Activated by 1/e^x')

# %%
# print(model.mean, model.std)
z = torch.randn(100, Z_DIM).to(DEVICE).view(100, 1, Z_DIM)
h = model.decode(z)
print(h.mean(), h.std())
# h = 1/torch.exp(h+1e-8)
# h = h / torch.sum(h, dim=1, keepdim=True) * 2 * torch.pi
plt.hist(h.cpu().detach().numpy().reshape(-1), bins=100)
plt.title("Distribution of Generated Data")
# Out:
# tensor(3.1834, device='cuda:0', grad_fn=<MeanBackward0>) tensor(0.8342, device='cuda:0', grad_fn=<StdBackward0>)
# Text(0.5, 1.0, 'Distribution of Generated Data')

# %% [markdown]
# Generate Data

# %%
def generate(num=1, mu_vals=None, sigma_vals=None, z_dim=Z_DIM):
    if mu_vals is None:
        mu = torch.zeros(1, z_dim).to(DEVICE, dtype=torch.float)
    else:
        mu = torch.tensor(mu_vals).to(DEVICE, dtype=torch.float).view(1, z_dim)

    if sigma_vals is None:
        sigma = torch.ones(1, z_dim).to(DEVICE, dtype=torch.float)
    else:
        sigma = torch.tensor(sigma_vals, dtype=torch.float).to(DEVICE).view(1, z_dim)

    generated_data = []

    model.eval()
    with torch.no_grad():
        for _ in range(num):
            z = model.sample(mu, sigma)
            out = model.decode(z)
            generated_data.append(out)

    # Convert the generated data to a numpy array
    generated_data = torch.cat(generated_data, dim=0)

    return generated_data.cpu().detach().numpy()

# %%
n = 100

# generated_data = h.view(-1, 100).cpu().detach().numpy()
generated_data = generate(num=n, sigma_vals=np.repeat(1, Z_DIM))
diff = 1 / (np.exp(generated_data) + 1e-8)
diff = diff / diff.sum(axis=1, keepdims=True) * 2 * np.pi
angle = np.cumsum(diff, axis=1)

fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(121)
ax.title.set_text("Generated Data")
for i in range(angle.shape[0]):
    ax.plot(angle[i])

ground_truth = cw[np.random.choice(range(cw.shape[0]), n)]
ground_truth_diff = 1 / (np.exp(ground_truth) + 1e-8)
ground_truth_diff = (
    ground_truth_diff / ground_truth_diff.sum(axis=1, keepdims=True) * 2 * np.pi
)
ground_truth_angle = np.cumsum(ground_truth_diff, axis=1)

ax = fig.add_subplot(122)
ax.title.set_text("Ground Truth Data")
for i in range(ground_truth_angle.shape[0]):
    ax.plot(ground_truth_angle[i])

# %%
x = np.linspace(0, 2 * np.pi, INPUT_DIM + 1)[:INPUT_DIM]
xs = np.exp(1j * x)

x_num = 5
y_num = int(np.floor(2 * n / x_num))
subfigure_size = 1.5

fig = plt.figure(figsize=(2 * x_num * subfigure_size, y_num * subfigure_size))
fig.subplots_adjust(hspace=0.05, wspace=0.05)

# Blue for generated data
for i in range(n):
    ys = np.exp(1j * angle[i])
    try:
        r, _ = geodesicwelding(ys, [], ys, xs)
    except:
        pass
    k = i // x_num * 2 * x_num + i % x_num + 1
    plt.subplot(y_num, 2 * x_num, k)
    plt.scatter(r.real, r.imag, s=0.3)
    plt.axis("off")

# Red for ground truth data
for i in range(n):
    ys = np.exp(1j * ground_truth_angle[i])
    try:
        r, _ = geodesicwelding(ys, [], ys, xs)
    except:
        pass
    k = i // x_num * 2 * x_num + i % x_num + 1 + x_num
    plt.subplot(y_num, 2 * x_num, k)
    plt.scatter(r.real, r.imag, s=0.3, color="r")
    plt.axis("off")
