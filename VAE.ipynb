# %% [markdown]
# ## VAE

# %% [markdown]
# Import required packages

# %%
import torch
from torch import optim
from ResVAE import ResVariationalAutoEncoder  # Assuming you have a VAE model defined in 'model.py'
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from train import load_cw
import h5py
from geodesicwelding import geodesicwelding


DEVICE = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
MAT_PATH = 'data/preprocessed.mat'

cw = load_cw(MAT_PATH)
cw_tensor = torch.tensor(cw)
train_data = TensorDataset(cw_tensor)

# %% [markdown]
# Training

# %%
# Configuration

INPUT_DIM = 100  # Adjusted input dimension to match your complex data
H_DIM = 1000
Z_DIM = 2
H_LAYERS = [2]
LR_RATE = 1e-3
BATCH_SIZE = 1024

torch.manual_seed(717)
train_loader = DataLoader(dataset=train_data, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)

## Init model
model = ResVariationalAutoEncoder(input_dim=INPUT_DIM, h_dim=H_DIM, h_layers=H_LAYERS, z_dim=Z_DIM).to(DEVICE)
model.initial()

## Load model
# model = torch.load('VAE_theta+bias1.pth')

optimizer = optim.Adam(model.parameters(), lr=LR_RATE, weight_decay=1e-5, betas=(0.5, 0.999))
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[8000], gamma=0.5)

model.to(DEVICE)

loader_size = len(train_loader)
loss_list_dict = {}
# loss_list = np.zeros(loader_size)  # To store reconstruction diff losses
# recon_loss_list = np.zeros(loader_size)  # To store reconstruction losses
# kl_loss_list = np.zeros(loader_size)         # To store KL divergence losses

# %%
NUM_EPOCHS = 20000

def get_kl_rate(epoch, n=500, m=1000):
    if epoch < m:
        return 0
    else:
        return (epoch % n) / n

kl_rate = 0.1
model.train()
for epoch in range(NUM_EPOCHS):
    for i, [data] in enumerate(train_loader):
        data = data.to(DEVICE, dtype=torch.float32).view(data.shape[0], INPUT_DIM)
        x_reconstructed, mu, sigma = model(data)

        # Compute loss
        # kl_rate = get_kl_rate(epoch)
        loss_dict = model.loss(x_reconstructed, data, mu, sigma, kl_rate)

        # Backprop
        optimizer.zero_grad()
        loss_dict['loss'].backward()
        optimizer.step()
        scheduler.step()
        
        # Append losses to the lists
        for k, v in loss_dict.items():
            if k not in loss_list_dict:
                loss_list_dict[k] = np.zeros(loader_size)
            
            loss_list_dict[k][i] = v.item()

    # Calculate and print average losses for this epoch
    # avg_loss = loss_list.sum() / data_size
    # avg_recon_loss = recon_loss_list.sum() / data_size
    # avg_kl_loss = kl_loss_list.sum() / data_size
    # avg_loss = loss_list.mean()
    # avg_recon_loss = recon_loss_list.mean()
    # avg_kl_loss = kl_loss_list.mean()
    # avg_true_loss = true_loss_list.mean()

    if epoch % 100 == 0:
        print(f"Epoch {epoch}/{NUM_EPOCHS} | {', '.join([f'{k}: {v.mean():.4f}' for k, v in loss_list_dict.items()])}")
        
    if epoch % 1000 == 0:
        torch.save(model, './VAE_theta+bias1.pth')
# Out:
# Epoch 0/20000 | loss: 1332.2394, recon_loss: 1331.5924, kl_loss: 6.4700, true_loss: 2.1108
# Epoch 100/20000 | loss: 50.2205, recon_loss: 48.3947, kl_loss: 18.2586, true_loss: 0.2129
# Epoch 200/20000 | loss: 49.7652, recon_loss: 47.4847, kl_loss: 22.8052, true_loss: 0.2215
# Epoch 300/20000 | loss: 45.7580, recon_loss: 43.8105, kl_loss: 19.4753, true_loss: 0.2192
# Epoch 400/20000 | loss: 42.0587, recon_loss: 40.2705, kl_loss: 17.8816, true_loss: 0.1965
# Epoch 500/20000 | loss: 43.5359, recon_loss: 41.8274, kl_loss: 17.0850, true_loss: 0.1952
# Epoch 600/20000 | loss: 38.7263, recon_loss: 36.9985, kl_loss: 17.2785, true_loss: 0.1882
# Epoch 700/20000 | loss: 34.9294, recon_loss: 33.0920, kl_loss: 18.3743, true_loss: 0.1675
# Epoch 800/20000 | loss: 38.2379, recon_loss: 36.5529, kl_loss: 16.8501, true_loss: 0.1873
# Epoch 900/20000 | loss: 34.1293, recon_loss: 32.3404, kl_loss: 17.8890, true_loss: 0.1682
# Epoch 1000/20000 | loss: 39.7918, recon_loss: 38.2874, kl_loss: 15.0440, true_loss: 0.1850
# Epoch 1100/20000 | loss: 27.3948, recon_loss: 25.7214, kl_loss: 16.7343, true_loss: 0.1386
# Epoch 1200/20000 | loss: 28.6038, recon_loss: 27.0267, kl_loss: 15.7707, true_loss: 0.1418
# Epoch 1300/20000 | loss: 25.1152, recon_loss: 23.5077, kl_loss: 16.0750, true_loss: 0.1258
# Epoch 1400/20000 | loss: 28.6199, recon_loss: 27.1932, kl_loss: 14.2672, true_loss: 0.1421
# Epoch 1500/20000 | loss: 26.5071, recon_loss: 25.0114, kl_loss: 14.9568, true_loss: 0.1298
# Epoch 1600/20000 | loss: 24.1183, recon_loss: 22.5736, kl_loss: 15.4469, true_loss: 0.1217
# Epoch 1700/20000 | loss: 26.7392, recon_loss: 25.2259, kl_loss: 15.1333, true_loss: 0.1391
# Epoch 1800/20000 | loss: 27.2817, recon_loss: 25.9483, kl_loss: 13.3335, true_loss: 0.1350
# Epoch 1900/20000 | loss: 24.2368, recon_loss: 22.8089, kl_loss: 14.2784, true_loss: 0.1215
# Epoch 2000/20000 | loss: 22.9285, recon_loss: 21.4980, kl_loss: 14.3058, true_loss: 0.1155
# Epoch 2100/20000 | loss: 21.8700, recon_loss: 20.5008, kl_loss: 13.6919, true_loss: 0.1121
# Epoch 2200/20000 | loss: 22.5990, recon_loss: 21.1803, kl_loss: 14.1865, true_loss: 0.1127
# Epoch 2300/20000 | loss: 25.3020, recon_loss: 23.9587, kl_loss: 13.4327, true_loss: 0.1314
# Epoch 2400/20000 | loss: 22.5011, recon_loss: 21.1778, kl_loss: 13.2324, true_loss: 0.1141
# Epoch 2500/20000 | loss: 18.5685, recon_loss: 17.2343, kl_loss: 13.3425, true_loss: 0.0961
# Epoch 2600/20000 | loss: 18.9966, recon_loss: 17.6426, kl_loss: 13.5398, true_loss: 0.0954
# Epoch 2700/20000 | loss: 17.3723, recon_loss: 15.9941, kl_loss: 13.7819, true_loss: 0.0892
# Epoch 2800/20000 | loss: 16.2628, recon_loss: 14.8706, kl_loss: 13.9221, true_loss: 0.0800
# Epoch 2900/20000 | loss: 20.7045, recon_loss: 19.3927, kl_loss: 13.1185, true_loss: 0.0981
# Epoch 3000/20000 | loss: 15.9454, recon_loss: 14.5702, kl_loss: 13.7528, true_loss: 0.0763
# Epoch 3100/20000 | loss: 18.6670, recon_loss: 17.3588, kl_loss: 13.0820, true_loss: 0.0913
# Epoch 3200/20000 | loss: 14.9431, recon_loss: 13.5621, kl_loss: 13.8098, true_loss: 0.0689
# Epoch 3300/20000 | loss: 13.7378, recon_loss: 12.3628, kl_loss: 13.7506, true_loss: 0.0668
# Epoch 3400/20000 | loss: 17.7498, recon_loss: 16.3555, kl_loss: 13.9427, true_loss: 0.0865
# Epoch 3500/20000 | loss: 17.4895, recon_loss: 16.1042, kl_loss: 13.8530, true_loss: 0.0849
# Epoch 3600/20000 | loss: 31.6975, recon_loss: 30.6037, kl_loss: 10.9375, true_loss: 0.1559
# Epoch 3700/20000 | loss: 28.7677, recon_loss: 27.5701, kl_loss: 11.9767, true_loss: 0.1326
# Epoch 3800/20000 | loss: 18.0570, recon_loss: 16.7795, kl_loss: 12.7747, true_loss: 0.0823
# Epoch 3900/20000 | loss: 15.6606, recon_loss: 14.3677, kl_loss: 12.9298, true_loss: 0.0731
# Epoch 4000/20000 | loss: 16.4876, recon_loss: 15.1884, kl_loss: 12.9924, true_loss: 0.0778
# Epoch 4100/20000 | loss: 16.7109, recon_loss: 15.4135, kl_loss: 12.9739, true_loss: 0.0843
# Epoch 4200/20000 | loss: 22.9837, recon_loss: 21.8139, kl_loss: 11.6976, true_loss: 0.1042
# Epoch 4300/20000 | loss: 27.4544, recon_loss: 26.3368, kl_loss: 11.1760, true_loss: 0.1348
# Epoch 4400/20000 | loss: 18.0884, recon_loss: 16.9162, kl_loss: 11.7223, true_loss: 0.0854
# Epoch 4500/20000 | loss: 16.9243, recon_loss: 15.6592, kl_loss: 12.6508, true_loss: 0.0765
# Epoch 4600/20000 | loss: 15.3507, recon_loss: 14.1063, kl_loss: 12.4440, true_loss: 0.0733
# Epoch 4700/20000 | loss: 19.3290, recon_loss: 18.1643, kl_loss: 11.6471, true_loss: 0.0937
# Epoch 4800/20000 | loss: 16.5757, recon_loss: 15.3952, kl_loss: 11.8046, true_loss: 0.0726
# Epoch 4900/20000 | loss: 22.9163, recon_loss: 21.7188, kl_loss: 11.9755, true_loss: 0.1084
# Epoch 5000/20000 | loss: 16.7497, recon_loss: 15.5643, kl_loss: 11.8541, true_loss: 0.0763
# Epoch 5100/20000 | loss: 13.5270, recon_loss: 12.2806, kl_loss: 12.4639, true_loss: 0.0626
# Epoch 5200/20000 | loss: 13.4786, recon_loss: 12.1984, kl_loss: 12.8019, true_loss: 0.0597
# Epoch 5300/20000 | loss: 11.3529, recon_loss: 10.0444, kl_loss: 13.0845, true_loss: 0.0498
# Epoch 5400/20000 | loss: 11.4008, recon_loss: 10.0842, kl_loss: 13.1656, true_loss: 0.0490
# Epoch 5500/20000 | loss: 15.2168, recon_loss: 13.8874, kl_loss: 13.2934, true_loss: 0.0679
# Epoch 5600/20000 | loss: 24.2210, recon_loss: 23.1485, kl_loss: 10.7253, true_loss: 0.1250
# Epoch 5700/20000 | loss: 22.6172, recon_loss: 21.5617, kl_loss: 10.5551, true_loss: 0.1194
# Epoch 5800/20000 | loss: 22.2284, recon_loss: 21.1178, kl_loss: 11.1062, true_loss: 0.1170
# Epoch 5900/20000 | loss: 20.6036, recon_loss: 19.5419, kl_loss: 10.6172, true_loss: 0.1059
# Epoch 6000/20000 | loss: 23.1541, recon_loss: 22.0697, kl_loss: 10.8434, true_loss: 0.1139
# Epoch 6100/20000 | loss: 20.2019, recon_loss: 19.0882, kl_loss: 11.1375, true_loss: 0.1024
# Epoch 6200/20000 | loss: 22.4638, recon_loss: 21.3389, kl_loss: 11.2489, true_loss: 0.1156
# Epoch 6300/20000 | loss: 15.8137, recon_loss: 14.6485, kl_loss: 11.6514, true_loss: 0.0811
# Epoch 6400/20000 | loss: 18.3150, recon_loss: 17.1630, kl_loss: 11.5200, true_loss: 0.0920
# Epoch 6500/20000 | loss: 21.1670, recon_loss: 19.9866, kl_loss: 11.8036, true_loss: 0.1092
# Epoch 6600/20000 | loss: 14.2294, recon_loss: 13.0398, kl_loss: 11.8961, true_loss: 0.0732
# Epoch 6700/20000 | loss: 13.8731, recon_loss: 12.6833, kl_loss: 11.8978, true_loss: 0.0706
# Epoch 6800/20000 | loss: 16.0170, recon_loss: 14.8700, kl_loss: 11.4702, true_loss: 0.0804
# Epoch 6900/20000 | loss: 18.2275, recon_loss: 17.0799, kl_loss: 11.4759, true_loss: 0.0958
# Epoch 7000/20000 | loss: 14.2970, recon_loss: 13.1598, kl_loss: 11.3715, true_loss: 0.0735
# Epoch 7100/20000 | loss: 11.4269, recon_loss: 10.2370, kl_loss: 11.8984, true_loss: 0.0561
# Epoch 7200/20000 | loss: 24.2863, recon_loss: 23.2253, kl_loss: 10.6102, true_loss: 0.1211
# Epoch 7300/20000 | loss: 14.9210, recon_loss: 13.7544, kl_loss: 11.6654, true_loss: 0.0811
# Epoch 7400/20000 | loss: 15.9252, recon_loss: 14.6917, kl_loss: 12.3344, true_loss: 0.0811
# Epoch 7500/20000 | loss: 16.9667, recon_loss: 15.7608, kl_loss: 12.0595, true_loss: 0.0824
# Epoch 7600/20000 | loss: 10.3731, recon_loss: 9.1770, kl_loss: 11.9608, true_loss: 0.0508
# Epoch 7700/20000 | loss: 16.9744, recon_loss: 15.7991, kl_loss: 11.7526, true_loss: 0.0830
# Epoch 7800/20000 | loss: 17.2863, recon_loss: 16.0938, kl_loss: 11.9254, true_loss: 0.0872
# Epoch 7900/20000 | loss: 9.4442, recon_loss: 8.2385, kl_loss: 12.0578, true_loss: 0.0491
# Epoch 8000/20000 | loss: 10.3875, recon_loss: 9.1970, kl_loss: 11.9052, true_loss: 0.0495
# Epoch 8100/20000 | loss: 8.0731, recon_loss: 6.8573, kl_loss: 12.1585, true_loss: 0.0387
# Epoch 8200/20000 | loss: 7.6192, recon_loss: 6.4162, kl_loss: 12.0300, true_loss: 0.0359
# Epoch 8300/20000 | loss: 7.4103, recon_loss: 6.2137, kl_loss: 11.9652, true_loss: 0.0354
# Epoch 8400/20000 | loss: 6.5692, recon_loss: 5.3858, kl_loss: 11.8332, true_loss: 0.0309
# Epoch 8500/20000 | loss: 6.4436, recon_loss: 5.2696, kl_loss: 11.7403, true_loss: 0.0299
# Epoch 8600/20000 | loss: 5.9457, recon_loss: 4.7711, kl_loss: 11.7452, true_loss: 0.0268
# Epoch 8700/20000 | loss: 5.8442, recon_loss: 4.6763, kl_loss: 11.6795, true_loss: 0.0265
# Epoch 8800/20000 | loss: 5.4894, recon_loss: 4.3241, kl_loss: 11.6524, true_loss: 0.0239
# Epoch 8900/20000 | loss: 6.2980, recon_loss: 5.1364, kl_loss: 11.6161, true_loss: 0.0295
# Epoch 9000/20000 | loss: 5.4189, recon_loss: 4.2421, kl_loss: 11.7674, true_loss: 0.0239
# Epoch 9100/20000 | loss: 6.1470, recon_loss: 4.9741, kl_loss: 11.7286, true_loss: 0.0275
# Epoch 9200/20000 | loss: 4.5275, recon_loss: 3.3584, kl_loss: 11.6910, true_loss: 0.0190
# Epoch 9300/20000 | loss: 4.9648, recon_loss: 3.8015, kl_loss: 11.6323, true_loss: 0.0215
# Epoch 9400/20000 | loss: 6.9595, recon_loss: 5.7934, kl_loss: 11.6611, true_loss: 0.0329
# Epoch 9500/20000 | loss: 4.5527, recon_loss: 3.3780, kl_loss: 11.7469, true_loss: 0.0192
# Epoch 9600/20000 | loss: 16.5363, recon_loss: 15.3925, kl_loss: 11.4384, true_loss: 0.0932
# Epoch 9700/20000 | loss: 3.9676, recon_loss: 2.8031, kl_loss: 11.6443, true_loss: 0.0158
# Epoch 9800/20000 | loss: 3.7129, recon_loss: 2.5510, kl_loss: 11.6185, true_loss: 0.0144
# Epoch 9900/20000 | loss: 4.0594, recon_loss: 2.8974, kl_loss: 11.6201, true_loss: 0.0162
# Epoch 10000/20000 | loss: 8.3391, recon_loss: 7.1455, kl_loss: 11.9365, true_loss: 0.0407
# Epoch 10100/20000 | loss: 3.5780, recon_loss: 2.4219, kl_loss: 11.5611, true_loss: 0.0137
# Epoch 10200/20000 | loss: 8.5297, recon_loss: 7.3352, kl_loss: 11.9453, true_loss: 0.0420
# Epoch 10300/20000 | loss: 3.7380, recon_loss: 2.5889, kl_loss: 11.4907, true_loss: 0.0143
# Epoch 10400/20000 | loss: 4.1674, recon_loss: 3.0062, kl_loss: 11.6113, true_loss: 0.0179
# Epoch 10500/20000 | loss: 3.5262, recon_loss: 2.3707, kl_loss: 11.5551, true_loss: 0.0136
# Epoch 10600/20000 | loss: 3.2798, recon_loss: 2.1349, kl_loss: 11.4487, true_loss: 0.0120
# Epoch 10700/20000 | loss: 3.1229, recon_loss: 1.9874, kl_loss: 11.3557, true_loss: 0.0112
# Epoch 10800/20000 | loss: 2.8463, recon_loss: 1.6877, kl_loss: 11.5865, true_loss: 0.0098
# Epoch 10900/20000 | loss: 2.9943, recon_loss: 1.8548, kl_loss: 11.3945, true_loss: 0.0106
# Epoch 11000/20000 | loss: 2.8670, recon_loss: 1.7352, kl_loss: 11.3178, true_loss: 0.0099
# Epoch 11100/20000 | loss: 3.0266, recon_loss: 1.8927, kl_loss: 11.3390, true_loss: 0.0107
# Epoch 11200/20000 | loss: 3.4956, recon_loss: 2.3412, kl_loss: 11.5444, true_loss: 0.0134
# Epoch 11300/20000 | loss: 2.9797, recon_loss: 1.8475, kl_loss: 11.3222, true_loss: 0.0109
# Epoch 11400/20000 | loss: 2.8184, recon_loss: 1.6892, kl_loss: 11.2925, true_loss: 0.0099
# Epoch 11500/20000 | loss: 3.1892, recon_loss: 2.0445, kl_loss: 11.4462, true_loss: 0.0130
# Epoch 11600/20000 | loss: 2.6568, recon_loss: 1.5004, kl_loss: 11.5646, true_loss: 0.0091
# Epoch 11700/20000 | loss: 2.8449, recon_loss: 1.7146, kl_loss: 11.3030, true_loss: 0.0104
# Epoch 11800/20000 | loss: 2.8689, recon_loss: 1.7434, kl_loss: 11.2556, true_loss: 0.0097
# Epoch 11900/20000 | loss: 4.0654, recon_loss: 2.9282, kl_loss: 11.3722, true_loss: 0.0158
# Epoch 12000/20000 | loss: 2.6096, recon_loss: 1.4770, kl_loss: 11.3260, true_loss: 0.0089
# Epoch 12100/20000 | loss: 2.6181, recon_loss: 1.4862, kl_loss: 11.3194, true_loss: 0.0085
# Epoch 12200/20000 | loss: 2.6540, recon_loss: 1.4880, kl_loss: 11.6602, true_loss: 0.0090
# Epoch 12300/20000 | loss: 2.4571, recon_loss: 1.2989, kl_loss: 11.5821, true_loss: 0.0075
# Epoch 12400/20000 | loss: 2.3035, recon_loss: 1.1670, kl_loss: 11.3659, true_loss: 0.0068
# Epoch 12500/20000 | loss: 4.6531, recon_loss: 3.5213, kl_loss: 11.3179, true_loss: 0.0195
# Epoch 12600/20000 | loss: 2.3971, recon_loss: 1.2727, kl_loss: 11.2442, true_loss: 0.0075
# Epoch 12700/20000 | loss: 2.2580, recon_loss: 1.1340, kl_loss: 11.2408, true_loss: 0.0066
# Epoch 12800/20000 | loss: 2.3143, recon_loss: 1.1766, kl_loss: 11.3769, true_loss: 0.0069
# Epoch 12900/20000 | loss: 8.3806, recon_loss: 7.2112, kl_loss: 11.6945, true_loss: 0.0396
# Epoch 13000/20000 | loss: 7.4829, recon_loss: 6.3282, kl_loss: 11.5468, true_loss: 0.0324
# Epoch 13100/20000 | loss: 2.2098, recon_loss: 1.1016, kl_loss: 11.0813, true_loss: 0.0067
# Epoch 13200/20000 | loss: 2.0107, recon_loss: 0.9084, kl_loss: 11.0232, true_loss: 0.0054
# Epoch 13300/20000 | loss: 2.6003, recon_loss: 1.4402, kl_loss: 11.6011, true_loss: 0.0095
# Epoch 13400/20000 | loss: 2.2323, recon_loss: 1.1062, kl_loss: 11.2620, true_loss: 0.0069
# Epoch 13500/20000 | loss: 2.1642, recon_loss: 1.0388, kl_loss: 11.2531, true_loss: 0.0064
# Epoch 13600/20000 | loss: 2.0078, recon_loss: 0.8760, kl_loss: 11.3184, true_loss: 0.0055
# Epoch 13700/20000 | loss: 2.0682, recon_loss: 0.9541, kl_loss: 11.1419, true_loss: 0.0055
# Epoch 13800/20000 | loss: 2.9553, recon_loss: 1.7910, kl_loss: 11.6427, true_loss: 0.0101
# Epoch 13900/20000 | loss: 2.3745, recon_loss: 1.2261, kl_loss: 11.4839, true_loss: 0.0063
# Epoch 14000/20000 | loss: 1.9433, recon_loss: 0.8304, kl_loss: 11.1287, true_loss: 0.0052
# Epoch 14100/20000 | loss: 2.5411, recon_loss: 1.4320, kl_loss: 11.0918, true_loss: 0.0082
# Epoch 14200/20000 | loss: 1.7815, recon_loss: 0.6525, kl_loss: 11.2900, true_loss: 0.0040
# Epoch 14300/20000 | loss: 1.8447, recon_loss: 0.7371, kl_loss: 11.0765, true_loss: 0.0044
# Epoch 14400/20000 | loss: 4.9595, recon_loss: 3.7846, kl_loss: 11.7487, true_loss: 0.0217
# Epoch 14500/20000 | loss: 1.7182, recon_loss: 0.6084, kl_loss: 11.0982, true_loss: 0.0038
# Epoch 14600/20000 | loss: 3.7759, recon_loss: 2.6313, kl_loss: 11.4467, true_loss: 0.0138
# Epoch 14700/20000 | loss: 4.7822, recon_loss: 3.6128, kl_loss: 11.6945, true_loss: 0.0213
# Epoch 14800/20000 | loss: 2.3353, recon_loss: 1.2104, kl_loss: 11.2488, true_loss: 0.0071
# Epoch 14900/20000 | loss: 5.6305, recon_loss: 4.4591, kl_loss: 11.7134, true_loss: 0.0241
# Epoch 15000/20000 | loss: 2.2689, recon_loss: 1.1483, kl_loss: 11.2057, true_loss: 0.0066
# Epoch 15100/20000 | loss: 1.9028, recon_loss: 0.7924, kl_loss: 11.1035, true_loss: 0.0046
# Epoch 15200/20000 | loss: 1.9025, recon_loss: 0.7828, kl_loss: 11.1971, true_loss: 0.0046
# Epoch 15300/20000 | loss: 2.8311, recon_loss: 1.6647, kl_loss: 11.6639, true_loss: 0.0100
# Epoch 15400/20000 | loss: 2.0486, recon_loss: 0.8809, kl_loss: 11.6765, true_loss: 0.0053
# Epoch 15500/20000 | loss: 1.8141, recon_loss: 0.7042, kl_loss: 11.0995, true_loss: 0.0042
# Epoch 15600/20000 | loss: 1.7166, recon_loss: 0.6109, kl_loss: 11.0575, true_loss: 0.0037
# Epoch 15700/20000 | loss: 5.4851, recon_loss: 4.3297, kl_loss: 11.5549, true_loss: 0.0266
# Epoch 15800/20000 | loss: 7.4187, recon_loss: 6.2995, kl_loss: 11.1915, true_loss: 0.0381
# Epoch 15900/20000 | loss: 5.0001, recon_loss: 3.8740, kl_loss: 11.2609, true_loss: 0.0233
# Epoch 16000/20000 | loss: 4.2078, recon_loss: 3.0881, kl_loss: 11.1968, true_loss: 0.0188
# Epoch 16100/20000 | loss: 3.4853, recon_loss: 2.3677, kl_loss: 11.1762, true_loss: 0.0150
# Epoch 16200/20000 | loss: 3.3828, recon_loss: 2.2766, kl_loss: 11.0616, true_loss: 0.0140
# Epoch 16300/20000 | loss: 3.1366, recon_loss: 2.0204, kl_loss: 11.1617, true_loss: 0.0128
# Epoch 16400/20000 | loss: 17.7898, recon_loss: 16.6851, kl_loss: 11.0470, true_loss: 0.0921
# Epoch 16500/20000 | loss: 2.9263, recon_loss: 1.8138, kl_loss: 11.1249, true_loss: 0.0109
# Epoch 16600/20000 | loss: 5.7743, recon_loss: 4.6195, kl_loss: 11.5474, true_loss: 0.0271
# Epoch 16700/20000 | loss: 2.6803, recon_loss: 1.5612, kl_loss: 11.1918, true_loss: 0.0095
# Epoch 16800/20000 | loss: 2.5573, recon_loss: 1.4606, kl_loss: 10.9665, true_loss: 0.0089
# Epoch 16900/20000 | loss: 3.2270, recon_loss: 2.0813, kl_loss: 11.4573, true_loss: 0.0135
# Epoch 17000/20000 | loss: 2.4537, recon_loss: 1.3517, kl_loss: 11.0198, true_loss: 0.0085
# Epoch 17100/20000 | loss: 2.4203, recon_loss: 1.3266, kl_loss: 10.9370, true_loss: 0.0081
# Epoch 17200/20000 | loss: 2.1431, recon_loss: 1.0355, kl_loss: 11.0764, true_loss: 0.0061
# Epoch 17300/20000 | loss: 2.3904, recon_loss: 1.2987, kl_loss: 10.9175, true_loss: 0.0080
# Epoch 17400/20000 | loss: 2.1203, recon_loss: 1.0291, kl_loss: 10.9119, true_loss: 0.0062
# Epoch 17500/20000 | loss: 12.1873, recon_loss: 11.0527, kl_loss: 11.3461, true_loss: 0.0634
# Epoch 17600/20000 | loss: 6.3333, recon_loss: 5.2010, kl_loss: 11.3237, true_loss: 0.0299
# Epoch 17700/20000 | loss: 2.6137, recon_loss: 1.5031, kl_loss: 11.1051, true_loss: 0.0087
# Epoch 17800/20000 | loss: 11.4301, recon_loss: 10.3158, kl_loss: 11.1432, true_loss: 0.0522
# Epoch 17900/20000 | loss: 2.5398, recon_loss: 1.4368, kl_loss: 11.0304, true_loss: 0.0082
# Epoch 18000/20000 | loss: 2.2475, recon_loss: 1.1483, kl_loss: 10.9920, true_loss: 0.0069
# Epoch 18100/20000 | loss: 3.0987, recon_loss: 1.9902, kl_loss: 11.0847, true_loss: 0.0117
# Epoch 18200/20000 | loss: 2.0204, recon_loss: 0.9208, kl_loss: 10.9962, true_loss: 0.0054
# Epoch 18300/20000 | loss: 4.0855, recon_loss: 2.9603, kl_loss: 11.2514, true_loss: 0.0181
# Epoch 18400/20000 | loss: 2.0356, recon_loss: 0.9392, kl_loss: 10.9638, true_loss: 0.0055
# Epoch 18500/20000 | loss: 1.9863, recon_loss: 0.8926, kl_loss: 10.9367, true_loss: 0.0053
# Epoch 18600/20000 | loss: 4.1459, recon_loss: 3.0219, kl_loss: 11.2393, true_loss: 0.0169
# Epoch 18700/20000 | loss: 3.5479, recon_loss: 2.4301, kl_loss: 11.1777, true_loss: 0.0139
# Epoch 18800/20000 | loss: 3.5420, recon_loss: 2.4253, kl_loss: 11.1666, true_loss: 0.0143
# Epoch 18900/20000 | loss: 10.0831, recon_loss: 8.9644, kl_loss: 11.1868, true_loss: 0.0478
# Epoch 19000/20000 | loss: 2.5945, recon_loss: 1.4912, kl_loss: 11.0329, true_loss: 0.0088
# Epoch 19100/20000 | loss: 2.3248, recon_loss: 1.2177, kl_loss: 11.0713, true_loss: 0.0072
# Epoch 19200/20000 | loss: 5.2799, recon_loss: 4.1230, kl_loss: 11.5696, true_loss: 0.0255
# Epoch 19300/20000 | loss: 2.4164, recon_loss: 1.3055, kl_loss: 11.1082, true_loss: 0.0078
# Epoch 19400/20000 | loss: 3.0884, recon_loss: 1.9804, kl_loss: 11.0793, true_loss: 0.0109
# Epoch 19500/20000 | loss: 2.7193, recon_loss: 1.6113, kl_loss: 11.0799, true_loss: 0.0091
# Epoch 19600/20000 | loss: 2.6752, recon_loss: 1.5766, kl_loss: 10.9854, true_loss: 0.0094
# Epoch 19700/20000 | loss: 2.5632, recon_loss: 1.4621, kl_loss: 11.0117, true_loss: 0.0084
# Epoch 19800/20000 | loss: 2.8074, recon_loss: 1.6699, kl_loss: 11.3752, true_loss: 0.0106
# Epoch 19900/20000 | loss: 2.3278, recon_loss: 1.1930, kl_loss: 11.3475, true_loss: 0.0075

# %%
c =cw[np.random.choice(range(cw.shape[0]),100)]
p = 1/np.exp(c)
print(p.mean(), p.std())
plt.hist(p.reshape(-1), bins=100)
plt.title('Original Distribution of Ground Truth ')
# Out:
# 0.06283185 0.056060378
# Text(0.5, 1.0, 'Original Distribution of Ground Truth ')

# %%
c =cw[np.random.choice(range(cw.shape[0]),100)]
print(c.mean(), c.std())
plt.hist(c.reshape(-1), bins=100)
plt.title('Distribution of Ground Truth Activated by 1/e^x')
# Out:
# 3.1619792 1.0218688
# Text(0.5, 1.0, 'Distribution of Ground Truth Activated by 1/e^x')

# %%
# print(model.mean, model.std)
z = torch.randn(100, Z_DIM).to(DEVICE).view(100, 1, Z_DIM)
h = model.decode(z)
print(h.mean(), h.std())
# h = 1/torch.exp(h+1e-8)
# h = h / torch.sum(h, dim=1, keepdim=True) * 2 * torch.pi
plt.hist(h.cpu().detach().numpy().reshape(-1), bins=100)
plt.title('Distribution of Generated Data')
# Out:
# tensor(3.0944, device='cuda:2', grad_fn=<MeanBackward0>) tensor(0.8037, device='cuda:2', grad_fn=<StdBackward0>)
# Text(0.5, 1.0, 'Distribution of Generated Data')

# %% [markdown]
# Generate Data

# %%
def generate(num=1, mu_vals=None, sigma_vals=None, z_dim=Z_DIM):
    if mu_vals is None:
        mu = torch.zeros(1, z_dim).to(DEVICE, dtype=torch.float)
    else:
        mu = torch.tensor(mu_vals).to(DEVICE, dtype=torch.float).view(1, z_dim)

    if sigma_vals is None:
        sigma = torch.ones(1, z_dim).to(DEVICE, dtype=torch.float)
    else:
        sigma = torch.tensor(sigma_vals, dtype=torch.float).to(DEVICE).view(1, z_dim)

    generated_data = []
    
    model.eval()
    with torch.no_grad():
        for _ in range(num):
            z = model.sample(mu, sigma)
            out = model.decode(z)
            generated_data.append(out)

    # Convert the generated data to a numpy array
    generated_data = torch.cat(generated_data, dim=0)

    return generated_data.cpu().detach().numpy()

# %%
n = 100

# generated_data = h.view(-1, 100).cpu().detach().numpy()
generated_data = generate(num=n, sigma_vals=np.repeat(1, Z_DIM))
diff = 1 / (np.exp(generated_data) + 1e-8)
diff = diff / diff.sum(axis=1, keepdims=True) * 2 * np.pi
angle = np.cumsum(diff, axis=1)

fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(121)
ax.title.set_text('Generated Data')
for i in range(angle.shape[0]):
    ax.plot(angle[i])
    
ground_truth = cw[np.random.choice(range(cw.shape[0]),n)]
ground_truth_diff = 1 / (np.exp(ground_truth) + 1e-8)
ground_truth_diff = ground_truth_diff / ground_truth_diff.sum(axis=1, keepdims=True) * 2 * np.pi
ground_truth_angle = np.cumsum(ground_truth_diff, axis=1)

ax = fig.add_subplot(122)
ax.title.set_text('Ground Truth Data')
for i in range(ground_truth_angle.shape[0]):
    ax.plot(ground_truth_angle[i])

# %%
x = np.linspace(0, 2*np.pi, INPUT_DIM+1)[:INPUT_DIM]
xs = np.exp(1j * x)

x_num = 5
y_num = int(np.floor(2*n / x_num))
subfigure_size = 1.5

fig = plt.figure(figsize=(2*x_num*subfigure_size, y_num*subfigure_size))
fig.subplots_adjust(hspace=0.05, wspace=0.05)

# Blue for generated data
for i in range(n):
    ys = np.exp(1j * angle[i])
    try:
        r, _ = geodesicwelding(ys, [], ys, xs)
    except:
        pass
    k = i//x_num*2*x_num + i%x_num+1
    plt.subplot(y_num, 2*x_num, k)
    plt.scatter(r.real, r.imag, s=0.3)
    plt.axis('off')

# Red for ground truth data
for i in range(n):
    ys = np.exp(1j * ground_truth_angle[i])
    try:
        r, _ = geodesicwelding(ys, [], ys, xs)
    except:
        pass
    k = i//x_num*2*x_num + i%x_num+1+x_num
    plt.subplot(y_num, 2*x_num, k)
    plt.scatter(r.real, r.imag, s=0.3, color='r')
    plt.axis('off')
